# %%
import pandas as pd
import numpy as np
import os,re
import hdf5_csv_conversion as h5
from sklearn import preprocessing
pd.options.mode.chained_assignment = None

# %%
# You will want this script to be in some sort of PATH/study/analysis folder
cur_dir = os.getcwd()
print(cur_dir)
# Out:
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\analysis

# %%
# You will want your data to be in some sort of PATH/study/logs folder (change it to whatever you like below)
rootdir = os.path.dirname(cur_dir) 
rootdir = os.path.join(rootdir,"logs")
print(rootdir)
# Out:
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs

# %%
# You will need the hdf5_csv_conversion.py script. This script does the heavey lifting and converts your hdf5 files to 4 csvs

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        if(re.search(".*\.hdf5$",file)):
            print(os.path.join(subdir, file))
            input_dummy = os.path.join(subdir, file)
            output_dummy = os.path.join(subdir,"dummy")
            h5.convert_hdf5(input_dummy,output_dummy)
# Out:
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\1\1_eyetracker_20211019-110350.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\1\
# Message events found :  207
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\1\message_events.csv
#
# Eyetracking events found :  44515
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\1\ eyetracking_events.csv
#
# Mouse press events found :  47229
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\1\ mouse_press_events.csv
#
# Keyboard press events found :  55
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\1\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\10\10_eyetracker_20211026-154333.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\10\
# Message events found :  207
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\10\message_events.csv
#
# Eyetracking events found :  51024
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\10\ eyetracking_events.csv
#
# Mouse press events found :  67011
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\10\ mouse_press_events.csv
#
# Keyboard press events found :  73
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\10\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\11\11_eyetracker_20211027-115756.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\11\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\11\message_events.csv
#
# Eyetracking events found :  52813
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\11\ eyetracking_events.csv
#
# Mouse press events found :  52282
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\11\ mouse_press_events.csv
#
# Keyboard press events found :  49
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\11\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\12\12_eyetracker_20211027-130216.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\12\
# Message events found :  207
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\12\message_events.csv
#
# Eyetracking events found :  53571
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\12\ eyetracking_events.csv
#
# Mouse press events found :  34501
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\12\ mouse_press_events.csv
#
# Keyboard press events found :  45
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\12\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\13\13_eyetracker_20211108-140042.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\13\
# Message events found :  207
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\13\message_events.csv
#
# Eyetracking events found :  55381
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\13\ eyetracking_events.csv
#
# Mouse press events found :  58411
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\13\ mouse_press_events.csv
#
# Keyboard press events found :  45
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\13\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\14\14_eyetracker_20211028-094946.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\14\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\14\message_events.csv
#
# Eyetracking events found :  57750
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\14\ eyetracking_events.csv
#
# Mouse press events found :  51632
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\14\ mouse_press_events.csv
#
# Keyboard press events found :  45
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\14\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\15\15_eyetracker_20211028-110420.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\15\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\15\message_events.csv
#
# Eyetracking events found :  62656
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\15\ eyetracking_events.csv
#
# Mouse press events found :  53266
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\15\ mouse_press_events.csv
#
# Keyboard press events found :  47
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\15\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\16\16_eyetracker_20211028-124235.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\16\
# Message events found :  207
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\16\message_events.csv
#
# Eyetracking events found :  53346
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\16\ eyetracking_events.csv
#
# Mouse press events found :  32797
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\16\ mouse_press_events.csv
#
# Keyboard press events found :  53
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\16\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\17\17_eyetracker_20211102-115850.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\17\
# Message events found :  207
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\17\message_events.csv
#
# Eyetracking events found :  46143
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\17\ eyetracking_events.csv
#
# Mouse press events found :  46447
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\17\ mouse_press_events.csv
#
# Keyboard press events found :  45
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\17\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\18\18_eyetracker_20211105-110336.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\18\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\18\message_events.csv
#
# Eyetracking events found :  57550
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\18\ eyetracking_events.csv
#
# Mouse press events found :  30169
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\18\ mouse_press_events.csv
#
# Keyboard press events found :  43
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\18\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\19\19_eyetracker_20211105-120501.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\19\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\19\message_events.csv
#
# Eyetracking events found :  85442
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\19\ eyetracking_events.csv
#
# Mouse press events found :  54731
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\19\ mouse_press_events.csv
#
# Keyboard press events found :  45
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\19\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\2\2_eyetracker_20211019-143216.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\2\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\2\message_events.csv
#
# Eyetracking events found :  99937
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\2\ eyetracking_events.csv
#
# Mouse press events found :  41862
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\2\ mouse_press_events.csv
#
# Keyboard press events found :  59
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\2\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\20\20_eyetracker_20211108-100621.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\20\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\20\message_events.csv
#
# Eyetracking events found :  53331
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\20\ eyetracking_events.csv
#
# Mouse press events found :  79446
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\20\ mouse_press_events.csv
#
# Keyboard press events found :  49
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\20\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\21\21_eyetracker_20211108-110426.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\21\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\21\message_events.csv
#
# Eyetracking events found :  52412
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\21\ eyetracking_events.csv
#
# Mouse press events found :  41362
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\21\ mouse_press_events.csv
#
# Keyboard press events found :  79
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\21\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\22\22_eyetracker_20211108-150035.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\22\
# Message events found :  206
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\22\message_events.csv
#
# Eyetracking events found :  49585
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\22\ eyetracking_events.csv
#
# Mouse press events found :  82821
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\22\ mouse_press_events.csv
#
# Keyboard press events found :  47
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\22\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\23\23_eyetracker_20211108-161338.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\23\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\23\message_events.csv
#
# Eyetracking events found :  80975
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\23\ eyetracking_events.csv
#
# Mouse press events found :  54661
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\23\ mouse_press_events.csv
#
# Keyboard press events found :  59
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\23\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\24\24_eyetracker_20211110-163511.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\24\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\24\message_events.csv
#
# Eyetracking events found :  51782
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\24\ eyetracking_events.csv
#
# Mouse press events found :  33554
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\24\ mouse_press_events.csv
#
# Keyboard press events found :  47
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\24\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\25\25_eyetracker_20211112-110814.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\25\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\25\message_events.csv
#
# Eyetracking events found :  85904
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\25\ eyetracking_events.csv
#
# Mouse press events found :  37197
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\25\ mouse_press_events.csv
#
# Keyboard press events found :  47
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\25\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\26\26_eyetracker_20211112-122938.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\26\
# Message events found :  207
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\26\message_events.csv
#
# Eyetracking events found :  40779
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\26\ eyetracking_events.csv
#
# Mouse press events found :  35276
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\26\ mouse_press_events.csv
#
# Keyboard press events found :  47
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\26\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\27\27_eyetracker_20211115-100319.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\27\
# Message events found :  206
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\27\message_events.csv
#
# Eyetracking events found :  73027
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\27\ eyetracking_events.csv
#
# Mouse press events found :  54008
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\27\ mouse_press_events.csv
#
# Keyboard press events found :  49
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\27\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\28\28_eyetracker_20211115-105921.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\28\
# Message events found :  206
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\28\message_events.csv
#
# Eyetracking events found :  68646
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\28\ eyetracking_events.csv
#
# Mouse press events found :  75895
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\28\ mouse_press_events.csv
#
# Keyboard press events found :  47
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\28\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\3\3_eyetracker_20211019-153800.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\3\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\3\message_events.csv
#
# Eyetracking events found :  106310
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\3\ eyetracking_events.csv
#
# Mouse press events found :  42527
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\3\ mouse_press_events.csv
#
# Keyboard press events found :  43
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\3\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\30\30_eyetracker_20211103-162154.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\30\
# Message events found :  207
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\30\message_events.csv
#
# Eyetracking events found :  76337
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\30\ eyetracking_events.csv
#
# Mouse press events found :  38889
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\30\ mouse_press_events.csv
#
# Keyboard press events found :  54
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\30\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\31\31_eyetracker_20211103-113351.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\31\
# Message events found :  207
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\31\message_events.csv
#
# Eyetracking events found :  44330
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\31\ eyetracking_events.csv
#
# Mouse press events found :  59170
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\31\ mouse_press_events.csv
#
# Keyboard press events found :  54
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\31\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\4\4_eyetracker_20211020-111232.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\4\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\4\message_events.csv
#
# Eyetracking events found :  58817
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\4\ eyetracking_events.csv
#
# Mouse press events found :  51382
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\4\ mouse_press_events.csv
#
# Keyboard press events found :  45
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\4\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\5\5_eyetracker_20211022-100317.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\5\
# Message events found :  207
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\5\message_events.csv
#
# Eyetracking events found :  64126
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\5\ eyetracking_events.csv
#
# Mouse press events found :  31692
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\5\ mouse_press_events.csv
#
# Keyboard press events found :  47
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\5\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\6\6_eyetracker_20211022-105417.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\6\
# Message events found :  207
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\6\message_events.csv
#
# Eyetracking events found :  50526
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\6\ eyetracking_events.csv
#
# Mouse press events found :  39179
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\6\ mouse_press_events.csv
#
# Keyboard press events found :  45
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\6\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\7\7_eyetracker_20211022-161014.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\7\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\7\message_events.csv
#
# Eyetracking events found :  57637
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\7\ eyetracking_events.csv
#
# Mouse press events found :  45989
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\7\ mouse_press_events.csv
#
# Keyboard press events found :  47
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\7\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\8\8_eyetracker_20211025-111141.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\8\
# Message events found :  208
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\8\message_events.csv
#
# Eyetracking events found :  95449
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\8\ eyetracking_events.csv
#
# Mouse press events found :  133604
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\8\ mouse_press_events.csv
#
# Keyboard press events found :  49
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\8\ keyboard_press_events.csv
#
# C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\9\9_eyetracker_20211026-141750.hdf5
# Directory is  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\9\
# Message events found :  207
# Done converting byte columns to string!
# Saved in NOW C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\9\message_events.csv
#
# Eyetracking events found :  67211
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\9\ eyetracking_events.csv
#
# Mouse press events found :  41776
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\9\ mouse_press_events.csv
#
# Keyboard press events found :  47
# Done converting byte columns to string!
# Saved in  C:\Users\Administrator\OneDrive - Temple University\Year II\Honesty\Study 5 - Eyetracker\logs\9\ keyboard_press_events.csv

# %%
def data_cleanup(data):
    # Remove the rows where neither eye is captured well
    clean_data = data[data["status"]!=22]
    
    # When status is 02 --> left eye is good, right eye is invalid
    clean_data.loc[(clean_data["status"]==2),"gaze_x"] = clean_data.loc[(clean_data["status"]==2),"left_gaze_x"]
    clean_data.loc[(clean_data["status"]==2),"gaze_y"] = clean_data.loc[(clean_data["status"]==2),"left_gaze_y"]
    
    # When status is 20 --> right eye is good, left eye is invalid
    clean_data.loc[(clean_data["status"]==20),"gaze_x"] = clean_data.loc[(clean_data["status"]==20),"right_gaze_x"]
    clean_data.loc[(clean_data["status"]==20),"gaze_y"] = clean_data.loc[(clean_data["status"]==20),"right_gaze_y"]
    
    # When status is 0, both eyes are well captured
    clean_data.loc[(clean_data["status"]==0),"gaze_x"] = (clean_data.loc[(clean_data["status"]==0),"left_gaze_x"] + clean_data.loc[(clean_data["status"]==0),"right_gaze_x"] )/2
    clean_data.loc[(clean_data["status"]==0),"gaze_y"] = (clean_data.loc[(clean_data["status"]==0),"left_gaze_y"] + clean_data.loc[(clean_data["status"]==0),"right_gaze_y"])/2
    return clean_data

# %%
def down_sample(clean_data,interval = 0.050):
    '''
    Description:
        We dont need all the time points for analysis.
        In this script we have set the sampling rate of the data to 50ms.
        This means that we will take the average gaze poistions in every 50ms window
        We average the event_id, time, and gaze positions in this interval window.
        This width is cofigurable using the interval variable
    '''
    min_time = clean_data["time"].min()
    max_time = clean_data["time"].max()
    x_gaze=[]
    y_gaze = []
    time_gaze=[]
    event_id=[]
    while(min_time <= max_time):
        #print(min_time)
        x_gaze.append(clean_data.loc[clean_data["time"].between(min_time, min_time+interval),"gaze_x"].mean())
        y_gaze.append(clean_data.loc[clean_data["time"].between(min_time, min_time+interval),"gaze_y"].mean())
        time_gaze.append(min_time+interval/2)
        event_id.append(clean_data.loc[clean_data["time"].between(min_time, min_time+interval),"event_id"].mean())
        #print(x_gaze)
        min_time = min_time+interval+.001
    
    x_gaze=pd.Series(x_gaze) 
    y_gaze=pd.Series(y_gaze) 
    time_gaze=pd.Series(time_gaze) 
    event_id=pd.Series(event_id)    
    
    sub_sampled_data = pd.DataFrame(dict(x_gaze = x_gaze, y_gaze = y_gaze,time_gaze=time_gaze,event_id = event_id))
    sub_sampled_data.dropna(inplace = True)
    return sub_sampled_data

# %%
def getStartEndEventIDs(message_events):
    start_end_ids =  message_events[message_events['category'].str.contains('trial_start|trial_end')][['category','text','event_id']]
    '''
    #You could add more markers and code here if you want
    # For instance if you want to know which is the start and end id explicitly through a column you could do something like the below
    start_end_ids.loc[start_end_ids['cateogry']=="trial_start",'start_or_end']="Start"
    start_end_ids.loc[start_end_ids['cateogry']=="trial_end",'start_or_end']="End"
    '''
    
    return(start_end_ids)

# %%
def eyetrackPreProcessing(OnlyStartEndIDS =0):
    Study_eyetracking=pd.DataFrame()
    Study_StartEndIDS = pd.DataFrame()
    for subdir, dirs, files in os.walk(rootdir):    
        for file in files:
            if(re.search(".*\.hdf5$",file)):
                print(os.path.join(subdir,"message_events.csv"))
                message_events_file = os.path.join(subdir, "message_events.csv")
                message_events = pd.read_csv(message_events_file)
                
                #get the subject ID
                pattern = "(.*)logs(.*?)message_events\.csv"
                substring = re.search(pattern, message_events_file).group(2)
                subj_id=substring.replace('\\','')
                
                #look for start and end event ids
                start_end_ids = getStartEndEventIDs(message_events)
                start_end_ids['id'] = subj_id
                start_end_ids.to_csv(os.path.join(subdir,"start_end_ids.csv"),index=False)
                
                Study_StartEndIDS = pd.concat([Study_StartEndIDS,start_end_ids])
                
                #cleanup the eyetracking data. Sometimes you want only want to get the start/end ids.
                # THe below code takes time to run.
                # So call the script with OnlyStartEndIDS set to 1 (anything apart from 0). This will bypass the below code
                if(OnlyStartEndIDS ==0):
                    eyetracking_events_file = os.path.join(subdir, "eyetracking_events.csv")
                    eyetracking_events = pd.read_csv(eyetracking_events_file)
                    eyetracking_events = data_cleanup(eyetracking_events)
                    # Changing the down sampling interval below.
                    eyetracking_events = down_sample(eyetracking_events)
                    eyetracking_events['id'] = subj_id
                    eyetracking_events.to_csv(os.path.join(subdir,"downsampled_eyetracking.csv"),index=False)
                    Study_eyetracking = pd.concat([Study_eyetracking,eyetracking_events])
    
    Study_StartEndIDS.to_csv(os.path.join(rootdir,"Study_StartEndIDS.csv"),index = False)
    
    if(OnlyStartEndIDS ==0):
        Study_eyetracking.to_csv(os.path.join(rootdir,"Study_eyetracking.csv"),index = False)

# %%
eyetrackPreProcessing(OnlyStartEndIDS=0)

# %%
# Mostly you will also want to see what % of data you lost due to the clean up and downsampling processes
# The below bit of code tells you that
summary_eyes = []
for subdir, dirs, files in os.walk(rootdir):    
        for file in files:
            if(re.search(".*\.hdf5$",file)):
                eyetracking_events_file = os.path.join(subdir, "eyetracking_events.csv")
                eyetracking_events = pd.read_csv(eyetracking_events_file)
                full_length = len(eyetracking_events)
                
                eyetracking_events = data_cleanup(eyetracking_events)
                
                reduced_length = len(eyetracking_events)
                
                downsampled_eyetracking_file = os.path.join(subdir, "downsampled_eyetracking.csv")
                downsampled_eyetracking_events = pd.read_csv(downsampled_eyetracking_file)
                down_length = len(downsampled_eyetracking_events)
                
                pattern = "(.*)logs(.*?)message_events\.csv"
                
                message_events_file = os.path.join(subdir, "message_events.csv")
                message_events = pd.read_csv(message_events_file)
                substring = re.search(pattern, message_events_file).group(2)
                subj_id=substring.replace('\\','')
                summary_eyes.append([subj_id,full_length,reduced_length,down_length])

summary_eyes
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1681: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = empty_value
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# [['1', 44515, 16590, 6462],
#  ['10', 51024, 5898, 2610],
#  ['11', 52813, 13819, 5614],
#  ['12', 53571, 51501, 17078],
#  ['13', 55381, 41506, 14180],
#  ['14', 57750, 4728, 2134],
#  ['15', 62656, 49925, 17186],
#  ['16', 53346, 47227, 15885],
#  ['17', 46143, 32110, 11405],
#  ['18', 57550, 14212, 5366],
#  ['19', 85442, 39398, 13630],
#  ['2', 99937, 59429, 20793],
#  ['20', 53331, 32673, 11983],
#  ['21', 52412, 47767, 15975],
#  ['22', 49585, 45512, 15480],
#  ['23', 80975, 20084, 7683],
#  ['24', 51782, 34668, 12175],
#  ['25', 85904, 3529, 1454],
#  ['26', 40779, 36648, 12221],
#  ['27', 73027, 70214, 23188],
#  ['28', 68646, 230, 131],
#  ['3', 106310, 103868, 34140],
#  ['30', 76337, 45094, 15735],
#  ['31', 44330, 971, 528],
#  ['4', 58817, 5080, 1937],
#  ['5', 64126, 864, 330],
#  ['6', 50526, 13445, 5978],
#  ['7', 57637, 54151, 18177],
#  ['8', 95449, 82005, 27934],
#  ['9', 67211, 16757, 6221]]
